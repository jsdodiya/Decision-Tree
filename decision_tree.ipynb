# %%
import pandas as pd
import seaborn as sns
# Load CSV file into DataFrame
df = pd.read_csv('Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 9)

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
from sklearn.preprocessing import Binarizer
bi = Binarizer(threshold=0.75)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.preprocessing import Binarizer
#       2 bi = Binarizer(threshold=0.75)
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:14
#      11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
# ---> 14 from .validation import _is_arraylike_not_scalar
#      17 class InvalidParameterError(ValueError, TypeError):
#      18     """Custom exception to be raised when the parameter of a class/method/function
#      19     does not have a valid type or value.
#      20     """
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:26
#      24 from .. import get_config as _get_config
#      25 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 26 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      27 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#      28 from ._isfinite import FiniteStatus, cy_isfinite
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_array_api.py:11
#       8 import scipy.special as special
#      10 from .._config import get_config
# ---> 11 from .fixes import parse_version
#      13 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#      16 def yield_namespaces(include_numpy_namespaces=True):
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\fixes.py:23
#      20 import scipy.stats
#      22 from ..externals._packaging.version import parse as parse_version
# ---> 23 from .parallel import _get_threadpool_controller
#      25 _IS_PYPY = platform.python_implementation() == "PyPy"
#      26 _IS_32BIT = 8 * struct.calcsize("P") == 32
#
# File c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:10
#       7 from functools import update_wrapper
#       9 import joblib
# ---> 10 from threadpoolctl import ThreadpoolController
#      12 from .._config import config_context, get_config
#      14 # Global threadpool controller instance that can be used to locally limit the number of
#      15 # threads without looping through all shared libraries every time.
#      16 # It should not be accessed directly and _get_threadpool_controller should be used
#      17 # instead.
#
# ImportError: cannot import name 'ThreadpoolController' from 'threadpoolctl' (c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\threadpoolctl.py)

# %%
from sklearn.preprocessing import Binarizer
bi = Binarizer(threshold=0.75)
df['Chance of Admit '] =bi.fit_transform(df[['Chance of Admit ']])

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1               1.0
# 1         1               1.0
# 2         1               0.0
# 3         1               1.0
# 4         0               0.0

# %%
x = df.drop('Chance of Admit ', axis=1)
y = df['Chance of Admit ']

# %%
x
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 395         1
# 396         1
# 397         1
# 398         0
# 399         1
#
# [400 rows x 8 columns]

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 395    1.0
# 396    1.0
# 397    1.0
# 398    0.0
# 399    1.0
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
y.astype(int)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Chance of Admit , Length: 400, dtype: int64

# %%
sns.countplot(x = y,palette='pastel')
# Out:
# C:\Users\jinen\AppData\Local\Temp\ipykernel_18484\3967273337.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = y,palette='pastel')
# <Axes: xlabel='Chance of Admit ', ylabel='count'>

# %%
y = y.astype(int)

# %%
y.value_counts()
# Out:
# Chance of Admit
# 0    228
# 1    172
# Name: count, dtype: int64

# %%
y.dtype
# Out:
# dtype('int64')

# %%
y.astype(int)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Chance of Admit , Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0, test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 8)

# %%
x_test.shape
# Out:
# (100, 8)

# %%
x_test
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 132         133        309          105                  5  3.5   3.5  8.56
# 309         310        308          110                  4  3.5   3.0  8.60
# 341         342        326          110                  3  3.5   3.5  8.76
# 196         197        306          105                  2  3.0   2.5  8.26
# 246         247        316          105                  3  3.0   3.5  8.73
# ..          ...        ...          ...                ...  ...   ...   ...
# 146         147        315          105                  3  2.0   2.5  8.48
# 135         136        314          109                  4  3.5   4.0  8.77
# 390         391        314          102                  2  2.0   2.5  8.24
# 264         265        325          110                  2  3.0   2.5  8.76
# 364         365        313          102                  3  3.5   4.0  8.90
#
#      Research
# 132         0
# 309         0
# 341         1
# 196         0
# 246         0
# ..        ...
# 146         0
# 135         1
# 390         0
# 264         1
# 364         1
#
# [100 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
result = pd.DataFrame({
    'actual' : y_test,
    'predicted' : y_pred
})

# %%
result
# Out:
#      actual  predicted
# 132       0          0
# 309       0          0
# 341       1          1
# 196       0          0
# 246       0          1
# ..      ...        ...
# 146       0          0
# 135       1          1
# 390       0          0
# 264       0          0
# 364       1          1
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        59
#            1       0.88      0.88      0.88        41
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.90      0.90       100
# weighted avg       0.90      0.90      0.90       100

# %%
new =[[136,314,109,4,3.5,4.0,8.77,1]]
classifier.predict(new)[0]
# Out:
# c:\Users\jinen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# np.int64(1)

# %%
# Out:
# [[136, 314, 109, 4, 3.5, 4.0, 8.77, 1]]

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(classifier, );

# %%
plot_tree(classifier, fontsize=8, filled=True, rounded=True);

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plot_tree(classifier, fontsize=8, filled=True, rounded=True);

# %%
plt.figure(figsize=(12,12))
plot_tree(classifier, fontsize=8, filled=True, rounded=True, feature_names=x.columns, class_names=['NA','AD']);
